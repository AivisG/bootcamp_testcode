# %%
import pandas as pd
data = pd.read_csv('data.csv')

# %%
#print(data.info())
print(data.head())
# Out:
#    WertX  WertY
# 0    197    200
# 1    156    160
# 2    100    102
# 3    168    170
# 4     71     72

# %%
print(data.describe())
# Out:
#             WertX       WertY
# count   25.000000   25.000000
# mean   128.240000  143.760000
# std     64.928987   69.855374
# min     21.000000   30.000000
# 25%     76.000000  100.000000
# 50%    126.000000  150.000000
# 75%    168.000000  190.000000
# max    241.000000  300.000000

# %%
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
import seaborn as sns
sns.boxplot(data)
plt.show()

# %%
plt.scatter(data['WertX'], data["WertY"])
#plt.xlabel('WertX')
#plt.ylabel('WertY')
plt.show()

# %%
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.show()
